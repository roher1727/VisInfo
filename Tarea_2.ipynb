# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
rendimiento = pd.read_csv("datos.csv")

# %%
rendimiento
# Out:
#    Proc.  Time [s]
# 0      1     29278
# 1     16       178
# 2     25        78
# 3     64        16
# 4    256         2
# 5    400         1

# %%
rendimiento["Speedup"] = [rendimiento["Time [s]"][0] / t for t in rendimiento["Time [s]"].values]
rendimiento["Efficiency"] = [s / p for p, s in zip(rendimiento["Proc."].values, rendimiento["Speedup"].values)]
rendimiento["Cost"] = [p * t for t, p in zip(rendimiento["Time [s]"].values, rendimiento["Proc."].values)]

# %%
rendimiento
# Out:
#    Proc.  Time [s]       Speedup  Efficiency   Cost
# 0      1     29278      1.000000    1.000000  29278
# 1     16       178    164.483146   10.280197   2848
# 2     25        78    375.358974   15.014359   1950
# 3     64        16   1829.875000   28.591797   1024
# 4    256         2  14639.000000   57.183594    512
# 5    400         1  29278.000000   73.195000    400

# %% [markdown]
# ## Graficación de valores obtenidos
#
# #### Speedup, Efficiency, Cost

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.set_size_inches(19, 7)
                    
ax1.set_title("Speedup")
ax1.plot(rendimiento["Proc."], rendimiento["Speedup"], marker='o', mec = 'r',linestyle='-')
ax1.set_xlabel("Processors")
ax1.set_ylabel("Speedup")
ax1.grid()

ax2.set_title("Efficiency")
ax2.plot(rendimiento["Proc."], rendimiento["Efficiency"], marker='o', mec = 'r',linestyle='-')
ax2.set_xlabel("Processors")
ax2.set_ylabel("Efficiency")
ax2.grid()

ax3.set_title("Cost")
ax3.plot(rendimiento["Proc."], rendimiento["Cost"], marker='o', mec = 'r',linestyle='-')
ax3.set_xlabel("Processors")
ax3.set_ylabel("Cost")
ax3.grid()


plt.show()

# %% [markdown]
# ## Obtención de valores relativos

# %%
rendimiento_rt = pd.read_csv("datos.csv")

p_prima = 16

rendimiento_rt["Speedup"] = [p_prima / t for t in rendimiento["Time [s]"].values]
rendimiento_rt["Efficiency"] = [p_prima*s / p for p, s in zip(rendimiento["Proc."].values, rendimiento["Speedup"].values)]
rendimiento_rt["Max.acel.rel"] = [p/p_prima for p in rendimiento["Proc."].values]

# %%
rendimiento_rt
# Out:
#    Proc.  Time [s]    Speedup   Efficiency  Max.acel.rel
# 0      1     29278   0.000546    16.000000        0.0625
# 1     16       178   0.089888   164.483146        1.0000
# 2     25        78   0.205128   240.229744        1.5625
# 3     64        16   1.000000   457.468750        4.0000
# 4    256         2   8.000000   914.937500       16.0000
# 5    400         1  16.000000  1171.120000       25.0000

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.set_size_inches(19, 7)
                    
ax1.set_title("Reltative Speedup")
ax1.plot(rendimiento_rt["Proc."], rendimiento_rt["Speedup"], marker='*', mec = 'r',linestyle='-')
ax1.set_xlabel("Processors")
ax1.set_ylabel("Reltative Speedup")
ax1.grid()

ax2.set_title("Relative Efficiency")
ax2.plot(rendimiento_rt["Proc."], rendimiento_rt["Efficiency"], marker='*', mec = 'r',linestyle='-')
ax2.set_xlabel("Processors")
ax2.set_ylabel("Relative Efficiency")
ax2.grid()

ax3.set_title("Maxima Aceleración Relativa")
ax3.plot(rendimiento_rt["Proc."], rendimiento_rt["Max.acel.rel"], marker='*', mec = 'r',linestyle='-')
ax3.set_xlabel("Processors")
ax3.set_ylabel("Maxima Aceleración Relativa")
ax3.grid()


plt.show()

# %% [markdown]
# # Edición de valor atípico
#
# Cambiamos el tiempo de un solo procesado de 29278 [s] a 430 [s]

# %%
rendimiento["Time [s]"][0] = 430

rendimiento["Speedup"] = [rendimiento["Time [s]"][0] / t for t in rendimiento["Time [s]"].values]
rendimiento["Efficiency"] = [s / p for p, s in zip(rendimiento["Proc."].values, rendimiento["Speedup"].values)]
rendimiento["Cost"] = [p * t for t, p in zip(rendimiento["Time [s]"].values, rendimiento["Proc."].values)]

rendimiento
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Proc.  Time [s]     Speedup  Efficiency  Cost
# 0      1       430    1.000000    1.000000   430
# 1     16       178    2.415730    0.150983  2848
# 2     25        78    5.512821    0.220513  1950
# 3     64        16   26.875000    0.419922  1024
# 4    256         2  215.000000    0.839844   512
# 5    400         1  430.000000    1.075000   400

# %% [markdown]
# ## Graficación de valores obtenidos
#
# #### Speedup, Efficiency, Cost

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.set_size_inches(19, 7)
                    
ax1.set_title("Speedup")
ax1.plot(rendimiento["Proc."], rendimiento["Speedup"], marker='*', mec = 'r',linestyle='-')
ax1.set_xlabel("Processors")
ax1.set_ylabel("Speedup")
ax1.grid()

ax2.set_title("Efficiency")
ax2.plot(rendimiento["Proc."], rendimiento["Efficiency"], marker='*', mec = 'r',linestyle='-')
ax2.set_xlabel("Processors")
ax2.set_ylabel("Efficiency")
ax2.grid()

ax3.set_title("Cost")
ax3.plot(rendimiento["Proc."], rendimiento["Cost"], marker='*', mec = 'r',linestyle='-')
ax1.set_xlabel("Processors")
ax1.set_ylabel("Cost")
ax3.grid()


plt.show()

# %% [markdown]
# ## Obtención de valores relativos

# %%
rendimiento_rt["Time [s]"][0] = 430
p_prima = 16
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
rendimiento_rt["Speedup"] = [p_prima / t for t in rendimiento["Time [s]"].values]
rendimiento_rt["Efficiency"] = [p_prima*s / p for p, s in zip(rendimiento["Proc."].values, rendimiento["Speedup"].values)]
rendimiento_rt["Max.acel.rel"] = [p/p_prima for p in rendimiento["Proc."].values]

rendimiento_rt

fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.set_size_inches(19, 7)
                    
ax1.set_title("Reltative Speedup")
ax1.plot(rendimiento_rt["Proc."], rendimiento_rt["Speedup"], marker='*', mec = 'r',linestyle='-')
ax1.set_xlabel("Processor")
ax1.set_ylabel("Reltative Speedup")
ax1.grid()

ax2.set_title("Relative Efficiency")
ax2.plot(rendimiento_rt["Proc."], rendimiento_rt["Efficiency"], marker='*', mec = 'r',linestyle='-')
ax2.set_xlabel("Processor")
ax2.set_ylabel("Relative Efficiency")
ax2.grid()

ax3.set_title("Maxima Aceleración Relativa")
ax3.plot(rendimiento_rt["Proc."], rendimiento_rt["Max.acel.rel"], marker='*', mec = 'r',linestyle='-')
ax3.set_xlabel("Processor")
ax3.set_ylabel("Maxima Aceleración Relativa")
ax3.grid()


plt.show()
